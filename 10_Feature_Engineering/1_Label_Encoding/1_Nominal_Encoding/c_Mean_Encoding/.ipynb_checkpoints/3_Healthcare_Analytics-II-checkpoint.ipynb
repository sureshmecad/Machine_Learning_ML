# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:/Users/deepusuresh/Documents/Data Science/10. Analytics Vidhya/1. Predict Loan Eligibility for Housing/1. Submission/train_ctrUa4K.csv")
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data['Loan_Status'] = data['Loan_Status'].map({'Y':1, 'N':0})

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# 0             1.0         Urban            1
# 1             1.0         Rural            0
# ...

# %%
data['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
data['Loan_Status'].value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %%
# check the target mean for both the categories
data.groupby('Education')['Loan_Status'].mean().round(2)
# Out:
# Education
# Graduate        0.71
# Not Graduate    0.61
# Name: Loan_Status, dtype: float64

# %%
data['Education'] = data['Education'].map({'Graduate' : 0.71, 'Not Graduate': 0.61})
data['Education'].head(10)
# Out:
# 0    0.71
# 1    0.71
# 2    0.71
# 3    0.61
# 4    0.71
# 5    0.71
# 6    0.61
# 7    0.71
# 8    0.71
# 9    0.71
# Name: Education, dtype: float64

# %%
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents  Education Self_Employed  \
# 0  LP001002   Male      No          0       0.71            No
# 1  LP001003   Male     Yes          1       0.71            No
# 2  LP001005   Male     Yes          0       0.71           Yes
# 3  LP001006   Male     Yes          0       0.61            No
# 4  LP001008   Male      No          0       0.71            No
# 5  LP001011   Male     Yes          2       0.71           Yes
# 6  LP001013   Male     Yes          0       0.61            No
# 7  LP001014   Male     Yes         3+       0.71            No
# 8  LP001018   Male     Yes          2       0.71            No
# 9  LP001020   Male     Yes          1       0.71            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...
