# %%
import pandas as pd

# %%
df = pd.read_csv("F:/03. Suresh/1. Material/05. Data Science/14. Jupyter/08. Data Sets/data.csv")
df
# Out:
#    Country        Age       Salary Purchased
# 0   France  44.000000  72000.00000        No
# 1    Spain  27.000000  48000.00000       Yes
# 2  Germany  30.000000  54000.00000        No
# 3    Spain  38.000000  61000.00000        No
# 4  Germany  40.000000  63777.77778       Yes
# 5   France  35.000000  58000.00000       Yes
# 6    Spain  38.777778  52000.00000        No
# 7   France  48.000000  79000.00000       Yes
# 8  Germany  50.000000  83000.00000        No
# 9   France  37.000000  67000.00000       Yes

# %%
df.shape
# Out:
# (10, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# Country      10 non-null object
# Age          10 non-null float64
# Salary       10 non-null float64
# Purchased    10 non-null object
# dtypes: float64(2), object(2)
# memory usage: 400.0+ bytes

# %%
df.dtypes
# Out:
# Country       object
# Age          float64
# Salary       float64
# Purchased     object
# dtype: object

# %% [raw]
# X = df.iloc[:,0:3]
#
#        (or)
#
# X = df.iloc[:,0:-1]
#
#        (or)
#
# X = df.iloc[:, :-1]

# %%
X2 = df.iloc[:, :-1]
X2
# Out:
#    Country        Age       Salary
# 0        0  44.000000  72000.00000
# 1        2  27.000000  48000.00000
# 2        1  30.000000  54000.00000
# 3        2  38.000000  61000.00000
# 4        1  40.000000  63777.77778
# 5        0  35.000000  58000.00000
# 6        2  38.777778  52000.00000
# 7        0  48.000000  79000.00000
# 8        1  50.000000  83000.00000
# 9        0  37.000000  67000.00000

# %%
X1 = df.iloc[:,0:3]
X1
# Out:
#    Country        Age       Salary
# 0   France  44.000000  72000.00000
# 1    Spain  27.000000  48000.00000
# 2  Germany  30.000000  54000.00000
# 3    Spain  38.000000  61000.00000
# 4  Germany  40.000000  63777.77778
# 5   France  35.000000  58000.00000
# 6    Spain  38.777778  52000.00000
# 7   France  48.000000  79000.00000
# 8  Germany  50.000000  83000.00000
# 9   France  37.000000  67000.00000

# %%
X = df.iloc[:,0:-1]
X
# Out:
#    Country        Age       Salary
# 0   France  44.000000  72000.00000
# 1    Spain  27.000000  48000.00000
# 2  Germany  30.000000  54000.00000
# 3    Spain  38.000000  61000.00000
# 4  Germany  40.000000  63777.77778
# 5   France  35.000000  58000.00000
# 6    Spain  38.777778  52000.00000
# 7   France  48.000000  79000.00000
# 8  Germany  50.000000  83000.00000
# 9   France  37.000000  67000.00000

# %%
Y = df.iloc[:,-1]
Y
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8     No
# 9    Yes
# Name: Purchased, dtype: object

# %% [markdown]
# ### Missing Data

# %%
df.isnull().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
from sklearn.preprocessing import impute.SimpleImputer as Imputer
imputer = Imputer(missing_values = 'NaN', strategy='mean', axis=0)
imputer = imputer.fit(X[:, 1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])
# Out:
#   File "<ipython-input-14-03cdbe694693>", line 1
#     from sklearn.preprocessing import impute.SimpleImputer as Imputer
#                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle["Country"] = le.fit_transform(dfle[["Country"],["Purchased"]])
dfle
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fd1e87c6d45a> in <module>
#       1 dfle = df
# ----> 2 dfle["Country"] = le.fit_transform(dfle[["Country"],["Purchased"]])
#       3 dfle
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# ...

# %%
X = dfle.iloc[:, 0:3]
X
# Out:
#    Country        Age       Salary
# 0        0  44.000000  72000.00000
# 1        2  27.000000  48000.00000
# 2        1  30.000000  54000.00000
# 3        2  38.000000  61000.00000
# 4        1  40.000000  63777.77778
# 5        0  35.000000  58000.00000
# 6        2  38.777778  52000.00000
# 7        0  48.000000  79000.00000
# 8        1  50.000000  83000.00000
# 9        0  37.000000  67000.00000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
X_train, Y_train, X_test, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression

# %%
model.fit(X_train, Y_train)
y_pred = model.predict(X_test)

# %%
X2 = df.iloc[:,0:-1].values
X2
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, 63777.77778],
#        ['France', 35.0, 58000.0],
#        ['Spain', 38.77777778, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)
