# %% [markdown]
# ## What is Kurtosis?

# %% [markdown]
# - **Kurtosis** is a statistical measure that defines how **heavily the tails** of a distribution differ from the tails of a **normal distribution**. In other words, kurtosis identifies whether the tails of a given distribution contain extreme values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Along with skewness, kurtosis is an important descriptive statistic of data distribution.
#
#
# - However, the two concepts must not be confused with each other.
#
#
# - **Skewness** essentially measures the **symmetry of the distribution**, while **kurtosis** determines the **heaviness of the distribution tails**.

# %% [markdown]
# __NOTE:__
#
# - A **large kurtosis** is associated with a **high level of risk** for an investment because it indicates that there are high probabilities of **extremely large and extremely small returns**.
#
#
# - On the other hand, a **small kurtosis** signals a **moderate level of risk** because the probabilities of extreme returns are **relatively low**.

# %% [markdown]
# ## Formula of Kurtosis
# #### ![image.png](attachment:image.png)

# %% [markdown]
# ## What is Excess Kurtosis?

# %% [markdown]
# - An **excess kurtosis** is a metric that compares the kurtosis of a distribution against the kurtosis of a normal distribution. The **kurtosis** of a **normal distribution equals 3**. Therefore, the excess kurtosis is found using the formula below:
#
#
# - **Excess Kurtosis = Kurtosis – 3**

# %% [markdown]
# ## Types of Kurtosis

# %% [markdown]
# - The types of **kurtosis** are determined by the excess kurtosis of a particular distribution. The **excess kurtosis** can take **positive or negative values, as well as values close to zero**.

# %% [markdown]
# ### 1. Mesokurtic
#
# - Data that follows a **mesokurtic distribution** shows an excess kurtosis of **zero or close to zero**.
#
#
# - This means that if the **data** follows a **normal distribution**, it follows a **mesokurtic distribution**.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Here **Beta** value will be **equal to 3** and when you calculate for excess kurtosis it will be **zero** because normalization for kurtosis is 3

# %% [markdown]
# ## 2. Leptokurtic
#
# - **Leptokurtic** indicates a **positive excess kurtosis**. The leptokurtic distribution shows **heavy tails on either side**, indicating **large outliers**.
#
#
# - In finance, a leptokurtic distribution shows that the investment returns may be prone to extreme values on either side. Therefore, an investment whose returns follow a leptokurtic distribution is considered to be risky.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Here **Beta** value will be **greater than 3 or more** this is also called positive excess kurtosis and it is **very risky** cannot be used until **normalized** and it's value is **greater than 0** when calculated

# %% [markdown]
# ## 3. Platykurtic
#
# - A **platykurtic** distribution shows a **negative excess kurtosis**. The kurtosis reveals a distribution with **flat tails**. The flat tails indicate the **small outliers** in a distribution.
#
#
# - In the finance context, the platykurtic distribution of the investment returns is desirable for investors because there is a small probability that the investment would experience extreme returns.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Here **Beta** value will be **less than 3** and it is **low risky** towards training the model with this data and it is also called negetive excess kurtosis and it's value is **lesser than 0** when calculated

# %% [markdown]
# ---------

# %% [markdown]
# ### Let's Look at Examples below to understand about kurtosis

# %% [markdown]
# ## Mesokurtic

# %%
from scipy.stats import kurtosis 
import numpy as np  
import pylab as p  
  
x = np.linspace( -6, 6, 2000) 
y = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x)**2  ) 
  
p.plot(x, y, '*')

# %%
print( '\nKurtosis for normal distribution :', kurtosis(y,fisher=False))
# Out:
# Kurtosis for normal distribution : 3.384490957810584

# %%
# when you check the excess of kurtosis
# Excess_of_Kurtosis=3.3844-3
3.3844-3
# Out:
# 0.38439999999999985

# %% [markdown]
# Which is nearly equal to 0 and its normally distributed

# %% [markdown]
# ## leptokurtic

# %%
from scipy.stats import kurtosis 
import numpy as np  
import pylab as p  
  
x = np.linspace( -8, 8, 8000 ) 
y = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x)**2  ) 
  
p.plot(x, y, '*')

# %%
print( '\nKurtosis for distribution :', kurtosis(y, fisher = False))
# Out:
# Kurtosis for distribution : 4.8629345349425135

# %%
# when you check the excess of kurtosis
# Excess_of_Kurtosis=4.8629-3
4.8629-3
# Out:
# 1.8628999999999998

# %% [markdown]
# Here it is +ve excess kurtosis and it's very risky

# %% [markdown]
# ## Platykurtic

# %%
from scipy.stats import kurtosis 
import numpy as np  
import pylab as p  
  
x = np.linspace( -1.5, 1.5, 2000 ) 
y = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x)**2  ) 
  
p.plot(x, y, '*')

# %%
print( '\nKurtosis for distribution :', kurtosis(y))
# Out:
# Kurtosis for distribution : -1.2864330358647957

# %%
# when you check the excess of kurtosis
# Excess_of_Kurtosis=-1.286-3
-1.286-3
# Out:
# -4.286
